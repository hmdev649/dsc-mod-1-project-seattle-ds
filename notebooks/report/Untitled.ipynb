# %%
yearlist = []
for i in range(15):
    if i < 8:
        yearlist[i] = '2016'
        yearlist = yearlist.append(yearlist[i])
    else: 
        yearlist[i] = '2020'
        yearlist = yearlist.append(yearlist[i])
yearlist
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-627111587050> in <module>
#       2 for i in range(15):
#       3     if i < 8:
# ----> 4         yearlist[i] = '2016'
#       5         yearlist = yearlist.append(yearlist[i])
#       6     else:
#
# IndexError: list assignment index out of range

# %%
range(15)
# Out:
# range(0, 15)

# %%
yearlist = []
for i in list(range(15)):
    year='2016'
    yearlist=yearlist.append(year)
    i +=1
year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-a724f661a750> in <module>
#       2 for i in list(range(15)):
#       3     year='2016'
# ----> 4     yearlist=yearlist.append(year)
#       5     i +=1
#       6 year
#
# AttributeError: 'NoneType' object has no attribute 'append'
